# %% [markdown]
# <a href="https://colab.research.google.com/github/sirinxa/my-first-pr/blob/main/Behind_the_Buzz_by_Sirinxa_Xavier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# Download train.csv
# !gdown --id 1AdeyVSkFROcqoz6VfBozx-N6G8tUoGPL
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1AdeyVSkFROcqoz6VfBozx-N6G8tUoGPL
# To: /content/train.csv
# 100% 2.04M/2.04M [00:00<00:00, 161MB/s]

# %%
# Download test.csv
# !gdown --id 1s0cnDOBMClkfto5oK4ICFcrhpoXPp8Tj
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1s0cnDOBMClkfto5oK4ICFcrhpoXPp8Tj
# To: /content/test.csv
# 100% 3.89M/3.89M [00:00<00:00, 50.2MB/s]

# %%
# Load data
dtrain = pd.read_csv('train.csv')

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(dtrain.drop('VERDICT', axis=1), dtrain['VERDICT'], test_size=0.2,random_state=42)

# %%
# Define model architecture
model = tf.keras.Sequential([tf.keras.layers.Dense(64, activation='relu', input_shape=(9,)),tf.keras.layers.Dense(32, activation='relu'),tf.keras.layers.Dense(1, activation='sigmoid')])

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print('Validation loss:', loss)
print('Validation accuracy:', accuracy)
# Out:
# Epoch 1/10
# 820/820 [==============================] - 4s 4ms/step - loss: 464.3958 - accuracy: 0.8895 - val_loss: 128.1108 - val_accuracy: 0.7788
# Epoch 2/10
# 820/820 [==============================] - 2s 2ms/step - loss: 141.1980 - accuracy: 0.8920 - val_loss: 199.4873 - val_accuracy: 0.6341
# Epoch 3/10
# 820/820 [==============================] - 2s 2ms/step - loss: 105.3139 - accuracy: 0.8933 - val_loss: 64.8017 - val_accuracy: 0.9393
# Epoch 4/10
# 820/820 [==============================] - 2s 2ms/step - loss: 101.9801 - accuracy: 0.8911 - val_loss: 132.3588 - val_accuracy: 0.9439
# Epoch 5/10
# 820/820 [==============================] - 2s 2ms/step - loss: 87.7161 - accuracy: 0.8913 - val_loss: 139.7468 - val_accuracy: 0.9443
# Epoch 6/10
# 820/820 [==============================] - 2s 2ms/step - loss: 78.2584 - accuracy: 0.8915 - val_loss: 31.2275 - val_accuracy: 0.9373
# Epoch 7/10
# ...

# %%
# Generate predictions on test data and save as csv file
test_data = pd.read_csv('test.csv')
predictions = model.predict(test_data.drop('Id', axis=1))
submission = pd.DataFrame({'Id': test_data['Id'], 'VERDICT': predictions.flatten()})
submission.to_csv('sampleSubmission.csv', index=False)
import csv
with open('sampleSubmission.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for line in csv_reader:
        print(line)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'Id': '53922', 'VERDICT': '1.0'}
# {'Id': '53923', 'VERDICT': '1.0'}
# {'Id': '53924', 'VERDICT': '1.0'}
# {'Id': '53925', 'VERDICT': '1.0'}
# {'Id': '53926', 'VERDICT': '1.0'}
# {'Id': '53927', 'VERDICT': '1.0'}
# {'Id': '53928', 'VERDICT': '1.0'}
# {'Id': '53929', 'VERDICT': '1.0'}
# {'Id': '53930', 'VERDICT': '1.0'}
# {'Id': '53931', 'VERDICT': '1.0'}
# {'Id': '53932', 'VERDICT': '1.0'}
# {'Id': '53933', 'VERDICT': '1.0'}
# {'Id': '53934', 'VERDICT': '1.0'}
# {'Id': '53935', 'VERDICT': '1.0'}
# {'Id': '53936', 'VERDICT': '1.0'}
# {'Id': '53937', 'VERDICT': '1.0'}
# {'Id': '53938', 'VERDICT': '1.0'}
# {'Id': '53939', 'VERDICT': '1.0'}
# {'Id': '53940', 'VERDICT': '1.0'}
# {'Id': '53941', 'VERDICT': '1.0'}
# {'Id': '53942', 'VERDICT': '1.0'}
# {'Id': '53943', 'VERDICT': '1.0'}
# {'Id': '53944', 'VERDICT': '1.0'}
# {'Id': '53945', 'VERDICT': '1.0'}
# {'Id': '53946', 'VERDICT': '1.0'}
# {'Id': '53947', 'VERDICT': '1.0'}
# ...
